# %% [markdown]
# # Project 3 - Model optimization
#
# 1. Implement and optimal control strategy for regulator taps amd PV system reactive power
#     * **Objective** minimize voltage imbalance within the system
#     * **Constraint** system voltages remain within bounds
#
#     Run the simulation for the same time period as project 2 amd compare the results (max system voltage, minimum system voltage and max system imbalance) to results from project 2
